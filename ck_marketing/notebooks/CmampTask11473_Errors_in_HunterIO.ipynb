# %% [markdown]
# CONTENTS:

# %%
#!sudo /bin/bash -c "(source /venv/bin/activate; pip install --upgrade google-api-python-client)"

# %%
import importlib
import os

import ck_marketing.hunterio.hunter_api as cmhuhuap
import helpers.hgoogle_file_api as hgofiapi

importlib.reload(hgofiapi)
importlib.reload(cmhuhuap)
# Out:
# <module 'ck_marketing.hunterio.hunter_api' from '/app/ck_marketing/hunterio/hunter_api.py'>

# %%
hunter_api = os.environ.get("HUNTER_API_KEY")
drop_api = os.environ.get("DROPCONTACT_API_KEY")

# %%
creds = hgofiapi.get_credentials()

# %%
link = "https://docs.google.com/spreadsheets/d/1o07XnIArFdIjz0jTZuyPkldxBczhQhMywdF9Xe9kNmo/edit?gid=1379255156#gid=1379255156"
df = hgofiapi.read_google_file(link, "chatgpt_extract", credentials=creds)

# %%
df.head()
# Out:
#             Name                 Job Title    Company       Company Size  \
# 0  Brandon Tseng          Co-Founder & CEO  Shield AI  <10,000 employees
# 1     Ryan Tseng          Co-Founder & COO  Shield AI  <10,000 employees
# 2   Shane O'Hara   Chief Financial Officer  Shield AI  <10,000 employees
# 3  Craig O'Neill  Chief Technology Officer  Shield AI  <10,000 employees
# 4  Jennifer Dyer    Chief Strategy Officer  Shield AI  <10,000 employees
#
#                                          Source Link email
# 0  https://www.linkedin.com/in/brandon-tseng-5b3b...
# 1             https://www.linkedin.com/in/ryantseng/
# 2   https://www.linkedin.com/in/shane-ohara-6b139b2/
# 3          https://www.linkedin.com/in/craig-oneill/
# 4  https://www.linkedin.com/in/jennifer-dyer-8a7b...

# %%
df[["firstName", "lastName"]] = df["Name"].str.split(" ", n=1, expand=True)

# %%
df.head()
# Out:
#             Name                 Job Title    Company       Company Size  \
# 0  Brandon Tseng          Co-Founder & CEO  Shield AI  <10,000 employees
# 1     Ryan Tseng          Co-Founder & COO  Shield AI  <10,000 employees
# 2   Shane O'Hara   Chief Financial Officer  Shield AI  <10,000 employees
# 3  Craig O'Neill  Chief Technology Officer  Shield AI  <10,000 employees
# 4  Jennifer Dyer    Chief Strategy Officer  Shield AI  <10,000 employees
#
#                                          Source Link email firstName lastName
# 0  https://www.linkedin.com/in/brandon-tseng-5b3b...         Brandon    Tseng
# 1             https://www.linkedin.com/in/ryantseng/            Ryan    Tseng
# 2   https://www.linkedin.com/in/shane-ohara-6b139b2/           Shane   O'Hara
# 3          https://www.linkedin.com/in/craig-oneill/           Craig  O'Neill
# 4  https://www.linkedin.com/in/jennifer-dyer-8a7b...        Jennifer     Dyer

# %%
df.shape
# Out:
# (1143, 8)

# %%
df_test = df.iloc[50:60]

# %%
df_test
# Out:
#                  Name                              Job Title      Company  \
# 50   Michael D. Smith                                    CFO   SpotHopper
# 51   Sarah B. Johnson                                    COO   SpotHopper
# 52  Lucas R. Thompson                 Chief Strategy Officer   SpotHopper
# 53      Emma J. Davis            VP of Corporate Development   SpotHopper
# 54      Saurabh Sinha                       Co-Founder & CEO  Cricket.com
# 55        Ravi Bhatia                       Co-Founder & CTO  Cricket.com
# 56      Vaibhav Sinha                       Co-Founder & COO  Cricket.com
# 57         Amit Kumar  VP of Strategy & Business Development  Cricket.com
# 58      Synthesia CEO                                    CEO    Synthesia
# 59      Synthesia CFO                                    CFO    Synthesia
#
#          Company Size                                        Source Link  \
# 50  <10,000 employees   https://www.linkedin.com/in/michael-smith-654321
# 51  <10,000 employees   https://www.linkedin.com/in/sarah-johnson-789012
# 52  <10,000 employees  https://www.linkedin.com/in/lucas-thompson-345678
# 53  <10,000 employees      https://www.linkedin.com/in/emma-davis-901234
# 54  <10,000 employees           https://www.linkedin.com/in/saurabhsinha
# 55  <10,000 employees             https://www.linkedin.com/in/ravibhatia
# 56  <10,000 employees           https://www.linkedin.com/in/vaibhavsinha
# 57  <10,000 employees             https://www.linkedin.com/in/amittkumar
# 58  <10,000 employees          https://www.linkedin.com/in/synthesia-ceo
# 59  <10,000 employees          https://www.linkedin.com/in/synthesia-cfo
#
#    email  firstName     lastName
# 50          Michael     D. Smith
# 51            Sarah   B. Johnson
# 52            Lucas  R. Thompson
# 53             Emma     J. Davis
# 54          Saurabh        Sinha
# 55             Ravi       Bhatia
# 56          Vaibhav        Sinha
# 57             Amit        Kumar
# 58        Synthesia          CEO
# 59        Synthesia          CFO

# %%
acc_info = cmhuhuap.get_account_info()
acc_info
# Out:
# {'searches': {'used': 1199, 'available': 5000, 'over_quota': 0},
#  'verifications': {'used': 0, 'available': 10000, 'over_quota': 0},
#  'reset_date': '2025-03-25'}

# %%
res = cmhuhuap.process_email(
    df_test, "firstName", "lastName", "Company", is_company=True
)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# cache {"('Michael', 'D. Smith', 'SpotHopper', True)": '_nan_', "('Sarah', 'B. Johnson', 'SpotHopper', True)": '_nan_', "('Lucas', 'R. Thompson', 'SpotHopper', True)": '_nan_', "('Emma', 'J. Davis', 'SpotHopper', True)": 'emma@spothopperapp.com', "('Saurabh', 'Sinha', 'Cricket.com', True)": '_nan_', "('Ravi', 'Bhatia', 'Cricket.com', True)": '_nan_', "('Vaibhav', 'Sinha', 'Cricket.com', True)": '_nan_', "('Amit', 'Kumar', 'Cricket.com', True)": '_nan_', "('Synthesia', 'CEO', 'Synthesia', True)": 'synthesia@synthesia.io', "('Synthesia', 'CFO', 'Synthesia', True)": 'synthesia@synthesia.io'}
# cache {"('Michael', 'D. Smith', 'SpotHopper', True)": '_nan_', "('Sarah', 'B. Johnson', 'SpotHopper', True)": '_nan_', "('Lucas', 'R. Thompson', 'SpotHopper', True)": '_nan_', "('Emma', 'J. Davis', 'SpotHopper', True)": 'emma@spothopperapp.com', "('Saurabh', 'Sinha', 'Cricket.com', True)": '_nan_', "('Ravi', 'Bhatia', 'Cricket.com', True)": '_nan_', "('Vaibhav', 'Sinha', 'Cricket.com', True)": '_nan_', "('Amit', 'Kumar', 'Cricket.com', True)": '_nan_', "('Synthesia', 'CEO', 'Synthesia', True)": 'synthesia@synthesia.io', "('Synthesia', 'CFO', 'Synthesia', True)": 'synthesia@synthesia.io'}
# cache {"('Michael', 'D. Smith', 'SpotHopper', True)": '_nan_', "('Sarah', 'B. Johnson', 'SpotHopper', True)": '_nan_', "('Lucas', 'R. Thompson', 'SpotHopper', True)": '_nan_', "('Emma', 'J. Davis', 'SpotHopper', True)": 'emma@spothopperapp.com', "('Saurabh', 'Sinha', 'Cricket.com', True)": '_nan_', "('Ravi', 'Bhatia', 'Cricket.com', True)": '_nan_', "('Vaibhav', 'Sinha', 'Cricket.com', True)": '_nan_', "('Amit', 'Kumar', 'Cricket.com', True)": '_nan_', "('Synthesia', 'CEO', 'Synthesia', True)": 'synthesia@synthesia.io', "('Synthesia', 'CFO', 'Synthesia', True)": 'synthesia@synthesia.io'}
# cache {"('Michael', 'D. Smith', 'SpotHopper', True)": '_nan_', "('Sarah', 'B. Johnson', 'SpotHopper', True)": '_nan_', "('Lucas', 'R. Thompson', 'SpotHopper', True)": '_nan_', "('Emma', 'J. Davis', 'SpotHopper', True)": 'emma@spothopperapp.com', "('Saurabh', 'Sinha', 'Cricket.com', True)": '_nan_', "('Ravi', 'Bhatia', 'Cricket.com', True)": '_nan_', "('Vaibhav', 'Sinha', 'Cricket.com', True)": '_nan_', "('Amit', 'Kumar', 'Cricket.com', True)": '_nan_', "('Synthesia', 'CEO', 'Synthesia', True)": 'synthesia@synthesia.io', "('Synthesia', 'CFO', 'Synthesia', True)": 'synthesia@synthesia.io'}
# cache {"('Michael', 'D. Smith', 'SpotHopper', True)": '_nan_', "('Sarah', 'B. Johnson', 'SpotHopper', True)": '_nan_', "('Lucas', 'R. Thompson', 'SpotHopper', True)": '_nan_', "('Emma', 'J. Davis', 'SpotHopper', True)": 'emma@spothopperapp.com', "('Saurabh', 'Sinha', 'Cricket.com', True)": '_nan_', "('Ravi', 'Bhatia', 'Cricket.com', True)": '_nan_', "('Vaibhav', 'Sinha', 'Cricket.com', True)": '_nan_', "('Amit', 'Kumar', 'Cricket.com', True)": '_nan_', "('Synthesia', 'CEO', 'Synthesia', True)": 'synthesia@synthesia.io', "('Synthesia', 'CFO', 'Synthesia', True)": 'synthesia@synthesia.io'}

# %%
res
# Out:
#                  Name                              Job Title      Company  \
# 50   Michael D. Smith                                    CFO   SpotHopper
# 51   Sarah B. Johnson                                    COO   SpotHopper
# 52  Lucas R. Thompson                 Chief Strategy Officer   SpotHopper
# 53      Emma J. Davis            VP of Corporate Development   SpotHopper
# 54      Saurabh Sinha                       Co-Founder & CEO  Cricket.com
# 55        Ravi Bhatia                       Co-Founder & CTO  Cricket.com
# 56      Vaibhav Sinha                       Co-Founder & COO  Cricket.com
# 57         Amit Kumar  VP of Strategy & Business Development  Cricket.com
# 58      Synthesia CEO                                    CEO    Synthesia
# 59      Synthesia CFO                                    CFO    Synthesia
#
#          Company Size                                        Source Link  \
# 50  <10,000 employees   https://www.linkedin.com/in/michael-smith-654321
# 51  <10,000 employees   https://www.linkedin.com/in/sarah-johnson-789012
# 52  <10,000 employees  https://www.linkedin.com/in/lucas-thompson-345678
# 53  <10,000 employees      https://www.linkedin.com/in/emma-davis-901234
# 54  <10,000 employees           https://www.linkedin.com/in/saurabhsinha
# 55  <10,000 employees             https://www.linkedin.com/in/ravibhatia
# 56  <10,000 employees           https://www.linkedin.com/in/vaibhavsinha
# 57  <10,000 employees             https://www.linkedin.com/in/amittkumar
# 58  <10,000 employees          https://www.linkedin.com/in/synthesia-ceo
# 59  <10,000 employees          https://www.linkedin.com/in/synthesia-cfo
#
#    email  firstName     lastName          hunterio.email  \
# 50          Michael     D. Smith                   _nan_
# 51            Sarah   B. Johnson                   _nan_
# 52            Lucas  R. Thompson                   _nan_
# 53             Emma     J. Davis  emma@spothopperapp.com
# 54          Saurabh        Sinha                   _nan_
# 55             Ravi       Bhatia                   _nan_
# 56          Vaibhav        Sinha                   _nan_
# 57             Amit        Kumar                   _nan_
# 58        Synthesia          CEO  synthesia@synthesia.io
# 59        Synthesia          CFO  synthesia@synthesia.io
#
#    hunterio.email_verification
# 50                     invalid
# 51                     invalid
# 52                     invalid
# 53                       valid
# 54                     invalid
# 55                     invalid
# 56                     invalid
# 57                     invalid
# 58                       valid
# 59                       valid
