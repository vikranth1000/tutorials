# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# %%
import datetime
import logging
import os

import pandas as pd
# /venv/lib/python3.12/site-packages/gspread_pandas/spread.py:401: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)` .replace("", np.nan)
pd.set_option('future.no_silent_downcasting', True)

import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hpandas as hpandas
import helpers.hprint as hprint
import helpers.hcache as hcache

#hcache.get_global_cache_info()
#hcache.clear_global_cache("all")

import config_root.config as cconfig

# %%
hdbg.init_logger(verbosity=logging.DEBUG)

_LOG = logging.getLogger(__name__)

_LOG.info("%s", henv.get_system_signature()[0])

hprint.config_notebook()
# Out:
# WARNING: Running in Jupyter
# DEBUG Effective logging level=10
# DEBUG Shut up 102 modules: botocore.parsers, botocore.paginate, s3fs, botocore.history, botocore, urllib3.connectionpool, matplotlib.axes, botocore.retryhandler, matplotlib.axes._axes, matplotlib.lines, matplotlib.backend_bases, matplotlib, matplotlib.figure, matplotlib.image, botocore.handlers, urllib3, botocore.hooks, fsspec.mapping, matplotlib.dates, matplotlib.textpath, asyncio, urllib3.connection, matplotlib.style, botocore.session, botocore.utils, matplotlib.style.core, botocore.configprovider, botocore.credentials, botocore.discovery, botocore.loaders, botocore.retries.special, botocore.regions, matplotlib.gridspec, botocore.awsrequest, botocore.monitoring, fsspec, matplotlib.artist, urllib3.util, botocore.response, matplotlib.colorbar, botocore.retries.adaptive, botocore.auth, botocore.endpoint, botocore.client, matplotlib.font_manager, matplotlib.ticker, matplotlib.axes._base, matplotlib.pyplot, botocore.tokens, urllib3.response, matplotlib.category, botocore.compress, botocore.args, botocore.endpoint_provider, botocore.waiter, matplotlib._afm, matplotlib.dviread, matplotlib.texmanager, matplotlib.text, botocore.compat, botocore.retries, botocore.httpsession, matplotlib._constrained_layout, urllib3.util.retry, matplotlib.mathtext, urllib3.poolmanager, matplotlib.axis, botocore.httpchecksum, matplotlib._layoutgrid, botocore.retries.standard
# INFO  > cmd='/venv/lib/python3.12/site-packages/ipykernel_launcher.py -f /home/.local/share/jupyter/runtime/kernel-43b50350-a8a1-425d-9be0-0191f199e471.json'
# DEBUG > (cd . && cd "$(git rev-parse --show-toplevel)/.." && (git rev-parse --is-inside-work-tree | grep -q true)) 2>&1
# DEBUG > (git rev-parse --show-toplevel) 2>&1
# DEBUG > (git branch --show-current) 2>&1
# DEBUG > (git rev-parse --short HEAD) 2>&1
# DEBUG > (git log --date=local --oneline --graph --date-order --decorate --pretty=format:'%h %<(8)%aN%  %<(65)%s (%>(14)%ar) %ad %<(10)%d' -3) 2>&1
# INFO  # Git
#   branch_name='CmampTask11020_Compute_yamm_stats'
#   hash='5404856e0'
#   # Last commits:
#     * 5404856e0 GP Saggese Update                                                            (   4 hours ago) Tue Jan 21 19:42:57 2025  (HEAD -> CmampTask11020_Compute_yamm_stats, origin/CmampTask11020_Compute_yamm_stats)
#     * 9685fb48f GP Saggese Lint                                                              (    2 days ago) Sun Jan 19 23:49:38 2025
#     * fe29ffe7c GP Saggese Update                                                            (    2 days ago) Sun Jan 19 23:43:06 2025
# # Machine info
#   system=Linux
#   node name=9b21dea71c71
#   release=6.10.14-linuxkit
#   version=#1 SMP Fri Nov 29 17:22:03 UTC 2024
#   machine=aarch64
#   processor=aarch64
#   cpu count=8
#   cpu freq=None
#   memory=svmem(total=8218251264, available=5881888768, percent=28.4, used=2117349376, free=140783616, active=2176892928, inactive=4672253952, buffers=1307979776, cached=4652138496, shared=11177984, slab=1058357248)
#   disk usage=sdiskusage(total=62671097856, used=30705344512, free=28749037568, percent=51.6)
# # Packages
#   python: 3.12.3
#   cvxopt: 1.3.2
#   cvxpy: 1.5.3
#   gluonnlp: ?
#   gluonts: ?
#   joblib: 1.4.2
#   mxnet: ?
#   numpy: 2.1.3
#   pandas: 2.2.3
#   pyarrow: 18.0.0
#   scipy: 1.14.1
#   seaborn: 0.13.2
#   sklearn: 1.5.2
#   statsmodels: 0.14.4

# %%
import gspread
print(gspread.__version__)

import gspread_pandas
print(gspread_pandas.__version__)

#gspread_pandas.conf.get_config()
print(gspread_pandas.conf.get_config()["project_id"])
# Out:
# 5.12.4
# 3.3.0
# gspread-gp

# %%
import helpers.hcache_simple as hscache

@hscache.simple_cache(cache_type="pickle", write_through=True)
def _get_cached_sheet_to_df(url: str, sheet_name: str) -> pd.DataFrame:
    _LOG.info(
        "Reading data from url='%s' sheet_name='%s'" % (url, sheet_name)
    )
    spread = gspread_pandas.Spread(url)
    df = spread.sheet_to_df(sheet=sheet_name, index=None)
    return df
# Out:
# DEBUG Creating _CACHE
# DEBUG Creating _CACHE_PERF
# DEBUG Creating _USER_CACHE_PROPERTY
# DEBUG Creating _SYSTEM_CACHE_PROPERTY
# DEBUG Loading from cache_property.system.pkl
# DEBUG Updating cache_property.system.pkl

# %%
print(hscache.cache_property_to_str("user", ""))
print(hscache.cache_property_to_str("system", ""))

# %%
url = "https://docs.google.com/spreadsheets/d/13hAmJ58Ois4CcxDoeP-Pwu_JR8kb11wcGHEaDQ5h_Gg"
#df = hyamm.get_cached_sheet_to_df(url, "email_verification")
df = _get_cached_sheet_to_df(url, "email_verification")

#hscache.flush_cache_to_disk()
df.head()
# Out:
# DEBUG Creating _CACHE
# DEBUG Creating _CACHE_PERF
# DEBUG Creating _USER_CACHE_PROPERTY
# DEBUG Creating _SYSTEM_CACHE_PROPERTY
# DEBUG Loading from cache_property.system.pkl
# DEBUG Loading disk cache for '_get_cached_sheet_to_df'
# DEBUG cache_type='pickle'
# DEBUG cache_type='pickle'
# DEBUG key=('https://docs.google.com/spreadsheets/d/13hAmJ58Ois4CcxDoeP-Pwu_JR8kb11wcGHEaDQ5h_Gg', 'email_verification')
# DEBUG cache_perf is None=True
# DEBUG force_refresh=False
# DEBUG Cache hit for key='('https://docs.google.com/spreadsheets/d/13hAmJ58Ois4CcxDoeP-Pwu_JR8kb11wcGHEaDQ5h_Gg', 'email_verification')'
#          fullName                   companyName   companyPosition          sweetSpot              rangePrice firstName  lastName                    hunterio_email hunterio_verification
# 0      Ahmed Jawa                 Niya Partners           Partner  Sweet spot: $1.5M    Range: $100K - $5.0M     Ahmed      Jawa                    a.jawa@niya.vc                 valid
# 1    Aadit Parikh          Sony Innovation Fund          Investor  Sweet spot: $1.5M    Range: $100K - $5.0M     Aadit    Parikh      aadit@sonyinnovationfund.com            accept_all
# 2    Ajay Agarwal         Bain Capital Ventures           Partner  Sweet spot: $1.5M  Range: $100K - $100.0M      Ajay   Agarwal  aagarwal@baincapitalventures.com                 valid
# 3  Aaron Applbaum               MizMaa Ventures  Managing Partner  Sweet spot: $3.0M      Range: $1M - $6.0M     Aaron  Applbaum         aaron.applbaum@mizmaa.com            accept_all
# 4       Aaron Tay  Auspac Investment Management          Investor  Sweet spot: $2.5M      Range: $1M - $5.0M     Aaron       Tay            aaron.tay@auspacim.com                 valid
