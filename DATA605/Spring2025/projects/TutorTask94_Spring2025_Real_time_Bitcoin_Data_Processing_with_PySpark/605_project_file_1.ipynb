# %% [markdown]
# ## Initialize Spark Session for Streaming
#
# This section creates a SparkSession configured for local streaming jobs. The `local[*]` master utilizes all available cores on the local machine for parallelism. It also sets the configuration to gracefully shut down the streaming context if the application is stopped. Logging level is reduced to "ERROR" to avoid excessive informational logs during execution.

# %%
# !uname -a
# Out:
# Linux rajesh 5.15.153.1-microsoft-standard-WSL2 #1 SMP Fri Mar 29 23:14:13 UTC 2024 x86_64 x86_64 x86_64 GNU/Linux

# %% [markdown]
# ## Fetch Real-Time Bitcoin Price from CoinGecko API
#
# This block defines the CoinGecko API endpoint and query parameters to retrieve the current price of Bitcoin in USD. The output directory is specified for storing fetched data as JSON files locally.

# %%
from pyspark.sql import SparkSession

# Create SparkSession for streaming (local[*] uses all local cores)
spark = SparkSession.builder \
    .appName("BitcoinStreaming") \
    .master("local[*]") \
    .config("spark.streaming.stopGracefullyOnShutdown", True) \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")
# Out:
# 25/05/01 09:25:58 WARN Utils: Your hostname, rajesh resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/05/01 09:25:58 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/01 09:25:59 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import requests, json, time
from datetime import datetime

api_url = "https://api.coingecko.com/api/v3/simple/price"
params = {'ids': 'bitcoin', 'vs_currencies': 'USD'}

output_dir = "/home/ubuntu/bitcoin_stream/"  # directory for JSON files

# %% [markdown]
# ## Setup for Storing Real-Time Bitcoin Data Locally
#
# This section sets up a local directory (`~/bitcoin_stream`) to store the real-time Bitcoin price data fetched from the CoinGecko API. It ensures the directory exists before saving any files.

# %%
#Dummy
import os
import json
import time
import requests
from datetime import datetime, timezone

output_dir = os.path.expanduser("~/bitcoin_stream")
os.makedirs(output_dir, exist_ok=True)  # Ensure directory exists

# %% [markdown]
# ## Fetch and Save Real-Time Bitcoin Prices
#
# The following loop fetches Bitcoin price data from the CoinGecko API at regular intervals (e.g., every 5 seconds), adds a UTC timestamp, and stores each data point as a separate JSON file in the previously created local directory.

# %%
# socket_server.py
import socket
import time
import json
import requests
from datetime import datetime, timezone

HOST = "localhost"
PORT = 5002
api_url = "https://api.coingecko.com/api/v3/simple/price"
params = {"ids": "bitcoin", "vs_currencies": "usd"}

s = socket.socket()
s.bind((HOST, PORT))
s.listen(1)
print("Socket server listening on port", PORT)
conn, addr = s.accept()
print(f"Connection from {addr}")

while True:
    response = requests.get(api_url, params=params)
    if response.status_code == 200:
        data = response.json()
        record = {
            "timestamp": datetime.now(timezone.utc).isoformat(),
            "price": data["bitcoin"]["usd"]
        }
        conn.sendall((json.dumps(record) + "\n").encode("utf-8"))
        print("Sent:", record)
    else:
        print("Failed to fetch data")
    time.sleep(5)
# Out:
# Socket server listening on port 5002
# Connection from ('127.0.0.1', 36664)
# Sent: {'timestamp': '2025-05-02T01:28:46.571674+00:00', 'price': 97106}
# Sent: {'timestamp': '2025-05-02T01:28:51.752836+00:00', 'price': 97106}
# Sent: {'timestamp': '2025-05-02T01:28:56.833625+00:00', 'price': 97106}
# Sent: {'timestamp': '2025-05-02T01:29:01.898484+00:00', 'price': 97106}
# Sent: {'timestamp': '2025-05-02T01:29:06.966206+00:00', 'price': 97106}
# Sent: {'timestamp': '2025-05-02T01:29:12.057395+00:00', 'price': 97106}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T01

# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:06:33.994323+00:00', 'price': 96871}
# Sent: {'timestamp': '2025-05-02T02:06:39.117697+00:00', 'price': 96871}
# Sent: {'timestamp': '2025-05-02T02:06:44.184819+00:00', 'price': 96871}
# Sent: {'timestamp': '2025-05-02T02:06:49.251934+00:00', 'price': 96871}
# Sent: {'timestamp': '2025-05-02T02:06:54.337447+00:00', 'price': 96871}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:08:00.265723+00:00', 'price': 96856}
# Sent: {'timestamp': '2025-05-02T02:08:05.329736+00:00', 'price': 96856}
# Sent: {'timestamp': '2025-05-02T02:08:10.398552+00:00', 'price': 96856}
# Sent: {'timestamp': '2025-05-02T02:08:15.491481+00:00', 'price': 96856}
# Sent: {'timestamp': '2025-05-02T02:08:20.570054+00:00', 'price': 96856}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:09:26.337937+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:09:31.401873+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:09:36.461586+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:09:41.584320+00:00', 'price': 96836}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:10:47.292630+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:10:52.370771+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:10:57.466868+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:11:02.534298+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:11:07.629847+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:11:12.704258+00:00', 'price': 96836}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:12:18.441578+00:00', 'price': 96855}
# Sent: {'timestamp': '2025-05-02T02:12:23.522360+00:00', 'price': 96855}
# Sent: {'timestamp': '2025-05-02T02:12:28.591306+00:00', 'price': 96855}
# Sent: {'timestamp': '2025-05-02T02:12:33.645554+00:00', 'price': 96855}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:13:39.482135+00:00', 'price': 96850}
# Sent: {'timestamp': '2025-05-02T02:13:44.553105+00:00', 'price': 96850}
# Sent: {'timestamp': '2025-05-02T02:13:49.624816+00:00', 'price': 96850}
# Sent: {'timestamp': '2025-05-02T02:13:54.727064+00:00', 'price': 96850}
# Sent: {'timestamp': '2025-05-02T02:13:59.823445+00:00', 'price': 96850}
# Sent: {'timestamp': '2025-05-02T02:14:04.896906+00:00', 'price': 96850}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:15:10.733875+00:00', 'price': 96845}
# Sent: {'timestamp': '2025-05-02T02:15:15.797869+00:00', 'price': 96845}
# Sent: {'timestamp': '2025-05-02T02:15:20.864640+00:00', 'price': 96845}
# Sent: {'timestamp': '2025-05-02T02:15:25.915936+00:00', 'price': 96845}
# Sent: {'timestamp': '2025-05-02T02:15:30.993882+00:00', 'price': 96845}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:16:36.750921+00:00', 'price': 96840}
# Sent: {'timestamp': '2025-05-02T02:16:41.832714+00:00', 'price': 96840}
# Sent: {'timestamp': '2025-05-02T02:16:46.933065+00:00', 'price': 96840}
# Sent: {'timestamp': '2025-05-02T02:16:51.988249+00:00', 'price': 96840}
# Sent: {'timestamp': '2025-05-02T02:16:57.061969+00:00', 'price': 96840}
# Sent: {'timestamp': '2025-05-02T02:17:02.116662+00:00', 'price': 96840}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:18:07.926263+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:18:13.011734+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:18:18.080048+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:18:23.152354+00:00', 'price': 96836}
# Sent: {'timestamp': '2025-05-02T02:18:28.234135+00:00', 'price': 96836}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:19:33.955884+00:00', 'price': 96838}
# Sent: {'timestamp': '2025-05-02T02:19:39.023265+00:00', 'price': 96838}
# Sent: {'timestamp': '2025-05-02T02:19:44.121661+00:00', 'price': 96838}
# Sent: {'timestamp': '2025-05-02T02:19:49.189663+00:00', 'price': 96848}
# Sent: {'timestamp': '2025-05-02T02:19:54.244843+00:00', 'price': 96848}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:21:00.030918+00:00', 'price': 96858}
# Sent: {'timestamp': '2025-05-02T02:21:05.089459+00:00', 'price': 96858}
# Sent: {'timestamp': '2025-05-02T02:21:10.145682+00:00', 'price': 96858}
# Sent: {'timestamp': '2025-05-02T02:21:15.219470+00:00', 'price': 96858}
# Sent: {'timestamp': '2025-05-02T02:21:20.298492+00:00', 'price': 96858}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:22:26.121244+00:00', 'price': 96863}
# Sent: {'timestamp': '2025-05-02T02:22:31.277647+00:00', 'price': 96863}
# Sent: {'timestamp': '2025-05-02T02:22:36.363457+00:00', 'price': 96863}
# Sent: {'timestamp': '2025-05-02T02:22:41.422501+00:00', 'price': 96863}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:23:47.227430+00:00', 'price': 96871}
# Sent: {'timestamp': '2025-05-02T02:23:52.297351+00:00', 'price': 96894}
# Sent: {'timestamp': '2025-05-02T02:23:57.358965+00:00', 'price': 96894}
# Sent: {'timestamp': '2025-05-02T02:24:02.464942+00:00', 'price': 96894}
# Sent: {'timestamp': '2025-05-02T02:24:07.537904+00:00', 'price': 96894}
# Sent: {'timestamp': '2025-05-02T02:24:12.598157+00:00', 'price': 96894}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:25:18.304195+00:00', 'price': 96889}
# Sent: {'timestamp': '2025-05-02T02:25:23.370788+00:00', 'price': 96889}
# Sent: {'timestamp': '2025-05-02T02:25:28.446405+00:00', 'price': 96889}
# Sent: {'timestamp': '2025-05-02T02:25:33.513976+00:00', 'price': 96889}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:26:39.285005+00:00', 'price': 96901}
# Sent: {'timestamp': '2025-05-02T02:26:44.391034+00:00', 'price': 96901}
# Sent: {'timestamp': '2025-05-02T02:26:49.464873+00:00', 'price': 96901}
# Sent: {'timestamp': '2025-05-02T02:26:54.560898+00:00', 'price': 96903}
# Sent: {'timestamp': '2025-05-02T02:26:59.677015+00:00', 'price': 96903}
# Sent: {'timestamp': '2025-05-02T02:27:04.774747+00:00', 'price': 96903}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:28:10.534311+00:00', 'price': 96923}
# Sent: {'timestamp': '2025-05-02T02:28:15.592325+00:00', 'price': 96923}
# Sent: {'timestamp': '2025-05-02T02:28:20.686390+00:00', 'price': 96923}
# Sent: {'timestamp': '2025-05-02T02:28:25.765371+00:00', 'price': 96923}
# Sent: {'timestamp': '2025-05-02T02:28:30.839003+00:00', 'price': 96923}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:29:36.573838+00:00', 'price': 96940}
# Sent: {'timestamp': '2025-05-02T02:29:41.636813+00:00', 'price': 96940}
# Sent: {'timestamp': '2025-05-02T02:29:46.785528+00:00', 'price': 96940}
# Sent: {'timestamp': '2025-05-02T02:29:51.862059+00:00', 'price': 96940}
# Sent: {'timestamp': '2025-05-02T02:29:57.018970+00:00', 'price': 96958}
# Sent: {'timestamp': '2025-05-02T02:30:02.095865+00:00', 'price': 96958}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:31:07.937213+00:00', 'price': 96971}
# Sent: {'timestamp': '2025-05-02T02:31:13.016306+00:00', 'price': 96971}
# Sent: {'timestamp': '2025-05-02T02:31:18.074946+00:00', 'price': 96971}
# Sent: {'timestamp': '2025-05-02T02:31:23.167035+00:00', 'price': 96971}
# Sent: {'timestamp': '2025-05-02T02:31:28.248712+00:00', 'price': 96971}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:32:34.023503+00:00', 'price': 96987}
# Sent: {'timestamp': '2025-05-02T02:32:39.107981+00:00', 'price': 96987}
# Sent: {'timestamp': '2025-05-02T02:32:44.171090+00:00', 'price': 96987}
# Sent: {'timestamp': '2025-05-02T02:32:49.264190+00:00', 'price': 96987}
# Sent: {'timestamp': '2025-05-02T02:32:54.349828+00:00', 'price': 96987}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:34:00.076849+00:00', 'price': 96991}
# Sent: {'timestamp': '2025-05-02T02:34:05.132373+00:00', 'price': 96993}
# Sent: {'timestamp': '2025-05-02T02:34:10.220660+00:00', 'price': 96993}
# Sent: {'timestamp': '2025-05-02T02:34:15.273805+00:00', 'price': 96993}
# Sent: {'timestamp': '2025-05-02T02:34:20.352087+00:00', 'price': 96993}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:35:26.162799+00:00', 'price': 97005}
# Sent: {'timestamp': '2025-05-02T02:35:31.224545+00:00', 'price': 97005}
# Sent: {'timestamp': '2025-05-02T02:35:36.280519+00:00', 'price': 97005}
# Sent: {'timestamp': '2025-05-02T02:35:41.383317+00:00', 'price': 97005}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:36:47.150826+00:00', 'price': 97013}
# Sent: {'timestamp': '2025-05-02T02:36:52.207111+00:00', 'price': 97013}
# Sent: {'timestamp': '2025-05-02T02:36:57.283720+00:00', 'price': 97013}
# Sent: {'timestamp': '2025-05-02T02:37:02.365457+00:00', 'price': 97013}
# Sent: {'timestamp': '2025-05-02T02:37:07.434684+00:00', 'price': 97010}
# Sent: {'timestamp': '2025-05-02T02:37:12.511343+00:00', 'price': 97010}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:38:18.261539+00:00', 'price': 96995}
# Sent: {'timestamp': '2025-05-02T02:38:23.354316+00:00', 'price': 96995}
# Sent: {'timestamp': '2025-05-02T02:38:28.445352+00:00', 'price': 96995}
# Sent: {'timestamp': '2025-05-02T02:38:33.519312+00:00', 'price': 96995}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:39:39.300065+00:00', 'price': 96991}
# Sent: {'timestamp': '2025-05-02T02:39:44.388283+00:00', 'price': 96991}
# Sent: {'timestamp': '2025-05-02T02:39:49.480442+00:00', 'price': 96991}
# Sent: {'timestamp': '2025-05-02T02:39:54.551659+00:00', 'price': 96991}
# Sent: {'timestamp': '2025-05-02T02:39:59.682967+00:00', 'price': 96991}
# Sent: {'timestamp': '2025-05-02T02:40:04.774628+00:00', 'price': 96991}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Sent: {'timestamp': '2025-05-02T02:41:10.778456+00:00', 'price': 96989}
# Sent: {'timestamp': '2025-05-02T02:41:15.861053+00:00', 'price': 96989}
# Sent: {'timestamp': '2025-05-02T02:41:20.934727+00:00', 'price': 96989}
# Sent: {'timestamp': '2025-05-02T02:41:25.994131+00:00', 'price': 96989}
# Sent: {'timestamp': '2025-05-02T02:41:31.084577+00:00', 'price': 96989}
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# Failed to fetch data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 32
#      30 else:
#      31     print("Failed to fetch data")
# ---> 32 time.sleep(5)
#
# KeyboardInterrupt:

# %% [markdown]
# ## There is other code runs parallely in different file  which Streaming Bitcoin Data from Socket to HDFS
